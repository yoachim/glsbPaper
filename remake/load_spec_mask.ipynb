# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from scipy.io import readsav

import bagpipes as pipes

# %%
"""The format of the spectrum returned by load_data should be a 2D array with three columns: 
wavelengths in Angstroms, fluxes in erg/s/cm^2/A and flux errors in the same units 
(can be changed to microJansksys with 
the spec_units keyword argument). These will be stored in galaxy.spectrum.
"""

def load_malin2(ID):
    if not hasattr(load_malin2, 'f1'):
        load_malin2.f1 = readsav('Malin2binned.sav')
    # Do some stuff to load up data for the object with the correct ID number
    ID = int(ID)
    rough_spec = load_malin2.f1['binned_spec'][ID,:] + 0 
    rough_err = load_malin2.f1['binned_err'][ID,:] + 0
    # Rough cut to chop off bad pixels
    
    bp = np.where((rough_spec < 0) | (rough_spec > 4))[0]
    
    rough_spec[bp] = 0
    rough_err[bp] = 1e6
    wave = np.exp(load_malin2.f1['wave'])
    bp = np.where((wave > 5565) & (wave < 5590))
    
    rough_spec[bp] = 0
    rough_err[bp] = 1e6
    
    bp = np.where(wave > 5780)
    rough_spec[bp] = 0
    rough_err[bp] = 1e6
    
    if ID == 5:
        bp = np.where(wave > 5770)
        rough_spec[bp] = 0
        rough_err[bp] = 1e6
        
        bp = np.where(wave < 3570)
        rough_spec[bp] = 0
        rough_err[bp] = 1e6
    
    rough_err[0:5] = 1e6
    
    good = np.where(rough_err < 1e6)
    
    spectrum = np.vstack([np.exp(load_malin2.f1['wave'])[good], rough_spec[good]*1e-18, rough_err[good]*1e-18])
    

    return spectrum.T

# %%
def load_ugc(ID):
    if not hasattr(load_ugc, 'f1'):
        load_ugc.f1 = readsav('UGC06614binned.sav')
    # Do some stuff to load up data for the object with the correct ID number
    ID = int(ID)
    rough_spec = load_ugc.f1['binned_spec'][ID, :] + 0 
    rough_err = load_ugc.f1['binned_err'][ID, :] + 0
    # Rough cut to chop off bad pixels
    bp = np.where((rough_spec < 0) | (rough_spec > 4))[0]
    
    rough_spec[bp] = 0
    rough_err[bp] = 1e6
    
    wave = np.exp(load_ugc.f1['wave'])
    good = np.where((3900 < wave) & (wave < 5500) & (rough_err < 1e6) & (rough_spec > 0))[0]
    
    spectrum = np.vstack([np.exp(load_ugc.f1['wave'])[good], rough_spec[good]*1e-18, rough_err[good]*1e-18])
    
    return spectrum.T

# %%
f1 = readsav('Malin2binned.sav')
f1['binned_spec'].shape
# Out:
# (6, 1024)

# %%
plt.plot(np.exp(f1['wave']), f1['binned_spec'][0,:])
plt.ylim([0,2])
plt.xlim([3500, 3600])
plt.plot(np.exp(f1['wave']), f1['binned_spec'][5,:])

# %%
f1['binned_spec'][0]
# Out:
# array([-6.78388355e-03,  3.65459055e-01,  4.78690952e-01, ...,
#        -2.75527169e+18, -2.75527169e+18, -2.62945924e+18])

# %%
# ok, how do I make this a bagpies object?
ack = load_malin2(0)
ack.shape
# Out:
# (987, 3)

# %%
f1 = readsav('UGC06614binned.sav')
plt.plot(np.exp(f1['wave']), f1['binned_spec'][3,:])
plt.ylim([0,2])
f1['binned_spec'].shape
# Out:
# (6, 1024)

# %%
# ok, we have a spectra loaded up. Not too shabby. 
for ID_number in range(6):
    galaxy = pipes.galaxy(ID_number, load_malin2, filt_list=[], photometry_exists=False)
    fig, ax = galaxy.plot()

# %%
# ok, we have a spectra loaded up. Not too shabby. 
for ID_number in range(6):
    galaxy = pipes.galaxy(ID_number, load_ugc, filt_list=[], photometry_exists=False)
    fig, ax = galaxy.plot()

# %%
# ok, we have a spectra loaded up. Not too shabby. 
ID_number = 0

galaxy = pipes.galaxy(ID_number, load_ugc, filt_list=[], photometry_exists=False)

fig, ax = galaxy.plot()

# %%
exp = {}                          # Tau model star formation history component
exp["age"] = 3.                   # Gyr
exp["tau"] = 0.75                 # Gyr
exp["massformed"] = 9.            # log_10(M*/M_solar)
exp["metallicity"] = 0.5          # Z/Z_oldsolar

dust = {}                         # Dust component
dust["type"] = "Calzetti"         # Define the shape of the attenuation curve
dust["Av"] = 0.2                  # magnitudes

model_components = {}                   # The model components dictionary
model_components["redshift"] = 1.0      # Observed redshift  
model_components["exponential"] = exp   
model_components["dust"] = dust

# %%
goodss_filt_list = np.loadtxt("filters/goodss_filt_list.txt", dtype="str")

# %%
model = pipes.model_galaxy(model_components, filt_list=goodss_filt_list)

# %%
fig = model.plot()
fig = model.sfh.plot()

# %%
dblplaw = {}                        
dblplaw["tau"] = (0., 15.)            
dblplaw["alpha"] = (0.01, 1000.)
dblplaw["beta"] = (0.01, 1000.)
dblplaw["alpha_prior"] = "log_10"
dblplaw["beta_prior"] = "log_10"
dblplaw["massformed"] = (1., 15.)
dblplaw["metallicity"] = (0.1, 2.)
dblplaw["metallicity_prior"] = "log_10"

nebular = {}
nebular["logU"] = -3.

dust = {}
dust["type"] = "CF00"
dust["eta"] = 2.
dust["Av"] = (0., 2.0)
dust["n"] = (0.3, 2.5)
dust["n_prior"] = "Gaussian"
dust["n_prior_mu"] = 0.7
dust["n_prior_sigma"] = 0.3

fit_instructions = {}
fit_instructions["redshift"] = (0.0, 0.1)
fit_instructions["t_bc"] = 0.01
#fit_instructions["redshift_prior"] = "Gaussian"
#fit_instructions["redshift_prior_mu"] = 0.9
#fit_instructions["redshift_prior_sigma"] = 0.05
fit_instructions["dblplaw"] = dblplaw 
fit_instructions["nebular"] = nebular
fit_instructions["dust"] = dust

fit_instructions["veldisp"] = (1., 2000.)   #km/s
fit_instructions["veldisp_prior"] = "log_10"

calib = {}
calib["type"] = "polynomial_bayesian"

calib["0"] = (0.5, 1.5) # Zero order is centred on 1, at which point there is no change to the spectrum.
calib["0_prior"] = "Gaussian"
calib["0_prior_mu"] = 1.0
calib["0_prior_sigma"] = 0.25

calib["1"] = (-0.5, 0.5) # Subsequent orders are centred on zero.
calib["1_prior"] = "Gaussian"
calib["1_prior_mu"] = 0.
calib["1_prior_sigma"] = 0.25

calib["2"] = (-0.5, 0.5)
calib["2_prior"] = "Gaussian"
calib["2_prior_mu"] = 0.
calib["2_prior_sigma"] = 0.25

fit_instructions["calib"] = calib

# XXX--does this actually get passed in?
mlpoly = {}
mlpoly["type"] = "polynomial_max_like"
mlpoly["order"] = 2

noise = {}
noise["type"] = "white_scaled"
noise["scaling"] = (1., 10.)
noise["scaling_prior"] = "log_10"
fit_instructions["noise"] = noise

# %%
ID_number = 0
galaxy = pipes.galaxy(ID_number, load_malin2, photometry_exists=False)
fit = pipes.fit(galaxy, fit_instructions, run="malin_test_%i" % ID_number)

#galaxy = pipes.galaxy(ID_number, load_ugc, photometry_exists=False)
#fit = pipes.fit(galaxy, fit_instructions, run="ugc_test_%i" % ID_number)

# %%
fit.fit(verbose=True)
# Out:
# Bagpipes: fitting object 0
#
#  MultiNest Warning: no resume file found, starting from scratch
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  400
#  dimensionality =   13
#  *****************************************************
#  Starting MultiNest
#  generating live points
#  live points generated, starting sampling
# Acceptance Rate:                        0.986842
# Replacements:                                450
# Total Samples:                               456
# Nested Sampling ln(Z):            **************
# Acceptance Rate:                        0.974659
# Replacements:                                500
# Total Samples:                               513
# Nested Sampling ln(Z):            **************
# Acceptance Rate:                        0.948276
# Replacements:                                550
# Total Samples:                               580
# Nested Sampling ln(Z):            **************
# Acceptance Rate:                        0.907716
# Replacements:                                600
# Total Samples:                               661
# Nested Sampling ln(Z):            **************
# Acceptance Rate:                        0.871314
# Replacements:                                650
# Total Samples:                               746
# Nested Sampling ln(Z):            **************
# Acceptance Rate:                        0.832342
# Replacements:                                700
# Total Samples:                               841
# Nested Sampling ln(Z):            **************
# Acceptance Rate:                        0.786164
# Replacements:                                750
# Total Samples:                               954
# Nested Sampling ln(Z):            -166801.523657
# Acceptance Rate:                        0.731930
# Replacements:                                800
# Total Samples:                              1093
# Nested Sampling ln(Z):             -97799.579615
# Acceptance Rate:                        0.692747
# Replacements:                                850
# Total Samples:                              1227
# Nested Sampling ln(Z):             -57656.927156
# Acceptance Rate:                        0.663228
# Replacements:                                900
# Total Samples:                              1357
# Nested Sampling ln(Z):             -39430.977077
# Acceptance Rate:                        0.620104
# Replacements:                                950
# Total Samples:                              1532
# Nested Sampling ln(Z):             -26561.529300
# Acceptance Rate:                        0.582411
# Replacements:                               1000
# Total Samples:                              1717
# Nested Sampling ln(Z):             -19085.284192
# Acceptance Rate:                        0.538462
# Replacements:                               1050
# Total Samples:                              1950
# Nested Sampling ln(Z):             -15184.112249
# Acceptance Rate:                        0.498866
# Replacements:                               1100
# Total Samples:                              2205
# Nested Sampling ln(Z):             -11414.428028
# Acceptance Rate:                        0.498915
# Replacements:                               1150
# Total Samples:                              2305
# Nested Sampling ln(Z):              -9962.740864
# Acceptance Rate:                        0.499168
# Replacements:                               1200
# Total Samples:                              2404
# Nested Sampling ln(Z):              -8607.424945
# Acceptance Rate:                        0.498405
# Replacements:                               1250
# Total Samples:                              2508
# Nested Sampling ln(Z):              -7422.254604
# Acceptance Rate:                        0.494485
# Replacements:                               1300
# Total Samples:                              2629
# Nested Sampling ln(Z):              -6660.529893
# Acceptance Rate:                        0.493782
# Replacements:                               1350
# Total Samples:                              2734
# Nested Sampling ln(Z):              -6144.998060
# Acceptance Rate:                        0.485942
# Replacements:                               1400
# Total Samples:                              2881
# Nested Sampling ln(Z):              -5784.560819
# Acceptance Rate:                        0.480132
# Replacements:                               1450
# Total Samples:                              3020
# Nested Sampling ln(Z):              -5475.540678
# Acceptance Rate:                        0.478469
# Replacements:                               1500
# Total Samples:                              3135
# Nested Sampling ln(Z):              -5189.722803
# Acceptance Rate:                        0.472705
# Replacements:                               1550
# Total Samples:                              3279
# Nested Sampling ln(Z):              -5015.467053
# Acceptance Rate:                        0.467973
# Replacements:                               1600
# Total Samples:                              3419
# Nested Sampling ln(Z):              -4856.454989
# Acceptance Rate:                        0.464658
# Replacements:                               1650
# Total Samples:                              3551
# Nested Sampling ln(Z):              -4703.831558
# Acceptance Rate:                        0.462082
# Replacements:                               1700
# Total Samples:                              3679
# Nested Sampling ln(Z):              -4560.397817
# Acceptance Rate:                        0.458355
# Replacements:                               1750
# Total Samples:                              3818
# Nested Sampling ln(Z):              -4476.060075
# Acceptance Rate:                        0.450113
# Replacements:                               1800
# Total Samples:                              3999
# Nested Sampling ln(Z):              -4399.671748
# Acceptance Rate:                        0.441422
# Replacements:                               1850
# Total Samples:                              4191
# Nested Sampling ln(Z):              -4321.774383
# Acceptance Rate:                        0.431132
# Replacements:                               1900
# Total Samples:                              4407
# Nested Sampling ln(Z):              -4271.833545
# Acceptance Rate:                        0.423821
# Replacements:                               1950
# Total Samples:                              4601
# Nested Sampling ln(Z):              -4212.034567
# Acceptance Rate:                        0.416233
# Replacements:                               2000
# Total Samples:                              4805
# Nested Sampling ln(Z):              -4162.680674
# Acceptance Rate:                        0.411895
# Replacements:                               2050
# Total Samples:                              4977
# Nested Sampling ln(Z):              -4117.950910
# Acceptance Rate:                        0.404858
# Replacements:                               2100
# Total Samples:                              5187
# Nested Sampling ln(Z):              -3975.710595
# Acceptance Rate:                        0.401344
# Replacements:                               2150
# Total Samples:                              5357
# Nested Sampling ln(Z):              -3783.665971
# Acceptance Rate:                        0.400510
# Replacements:                               2200
# Total Samples:                              5493
# Nested Sampling ln(Z):              -3589.876349
# Acceptance Rate:                        0.397386
# Replacements:                               2250
# Total Samples:                              5662
# Nested Sampling ln(Z):              -3423.175678
# Acceptance Rate:                        0.396278
# Replacements:                               2300
# Total Samples:                              5804
# Nested Sampling ln(Z):              -3204.909986
# Acceptance Rate:                        0.395423
# Replacements:                               2350
# Total Samples:                              5943
# Nested Sampling ln(Z):              -3050.978187
# Acceptance Rate:                        0.390434
# Replacements:                               2400
# Total Samples:                              6147
# Nested Sampling ln(Z):              -2914.299661
# Acceptance Rate:                        0.386985
# Replacements:                               2450
# Total Samples:                              6331
# Nested Sampling ln(Z):              -2782.665127
# Acceptance Rate:                        0.384379
# Replacements:                               2500
# Total Samples:                              6504
# Nested Sampling ln(Z):              -2699.373070
# Acceptance Rate:                        0.379013
# Replacements:                               2550
# Total Samples:                              6728
# Nested Sampling ln(Z):              -2597.259610
# Acceptance Rate:                        0.374910
# Replacements:                               2600
# Total Samples:                              6935
# Nested Sampling ln(Z):              -2532.005356
# Acceptance Rate:                        0.371773
# Replacements:                               2650
# Total Samples:                              7128
# Nested Sampling ln(Z):              -2462.648604
# Acceptance Rate:                        0.366948
# Replacements:                               2700
# Total Samples:                              7358
# Nested Sampling ln(Z):              -2410.920548
# Acceptance Rate:                        0.362176
# Replacements:                               2750
# Total Samples:                              7593
# Nested Sampling ln(Z):              -2349.838496
# Acceptance Rate:                        0.358928
# Replacements:                               2800
# Total Samples:                              7801
# Nested Sampling ln(Z):              -2306.193188
# Acceptance Rate:                        0.356295
# Replacements:                               2850
# Total Samples:                              7999
# Nested Sampling ln(Z):              -2270.711949
# Acceptance Rate:                        0.352970
# Replacements:                               2900
# Total Samples:                              8216
# Nested Sampling ln(Z):              -2234.992607
# Acceptance Rate:                        0.346488
# Replacements:                               2950
# Total Samples:                              8514
# Nested Sampling ln(Z):              -2202.451341
# Acceptance Rate:                        0.341958
# Replacements:                               3000
# Total Samples:                              8773
# Nested Sampling ln(Z):              -2172.032504
# Acceptance Rate:                        0.338776
# Replacements:                               3050
# Total Samples:                              9003
# Nested Sampling ln(Z):              -2135.159919
# Acceptance Rate:                        0.335425
# Replacements:                               3100
# Total Samples:                              9242
# Nested Sampling ln(Z):              -2103.606943
# Acceptance Rate:                        0.329257
# Replacements:                               3150
# Total Samples:                              9567
# Nested Sampling ln(Z):              -2077.656996
# Acceptance Rate:                        0.323723
# Replacements:                               3200
# Total Samples:                              9885
# Nested Sampling ln(Z):              -2050.761637
# Acceptance Rate:                        0.318846
# Replacements:                               3250
# Total Samples:                             10193
# Nested Sampling ln(Z):              -2019.930020
# Acceptance Rate:                        0.316274
# Replacements:                               3300
# Total Samples:                             10434
# Nested Sampling ln(Z):              -1997.306183
# Acceptance Rate:                        0.309726
# Replacements:                               3350
# Total Samples:                             10816
# Nested Sampling ln(Z):              -1970.238651
# Acceptance Rate:                        0.303816
# Replacements:                               3400
# Total Samples:                             11191
# Nested Sampling ln(Z):              -1940.772209
# Acceptance Rate:                        0.296137
# Replacements:                               3450
# Total Samples:                             11650
# Nested Sampling ln(Z):              -1921.936076
# Acceptance Rate:                        0.291303
# Replacements:                               3500
# Total Samples:                             12015
# Nested Sampling ln(Z):              -1895.981466
# Acceptance Rate:                        0.286498
# Replacements:                               3550
# Total Samples:                             12391
# Nested Sampling ln(Z):              -1873.411855
# Acceptance Rate:                        0.282530
# Replacements:                               3600
# Total Samples:                             12742
# Nested Sampling ln(Z):              -1851.630609
# Acceptance Rate:                        0.278754
# Replacements:                               3650
# Total Samples:                             13094
# Nested Sampling ln(Z):              -1836.115458
# Acceptance Rate:                        0.273547
# Replacements:                               3700
# Total Samples:                             13526
# Nested Sampling ln(Z):              -1812.460194
# Acceptance Rate:                        0.269842
# Replacements:                               3750
# Total Samples:                             13897
# Nested Sampling ln(Z):              -1786.936596
# Acceptance Rate:                        0.264827
# Replacements:                               3800
# Total Samples:                             14349
# Nested Sampling ln(Z):              -1766.693188
# Acceptance Rate:                        0.261017
# Replacements:                               3850
# Total Samples:                             14750
# Nested Sampling ln(Z):              -1748.536593
# Acceptance Rate:                        0.256275
# Replacements:                               3900
# Total Samples:                             15218
# Nested Sampling ln(Z):              -1730.964690
# Acceptance Rate:                        0.250857
# Replacements:                               3950
# Total Samples:                             15746
# Nested Sampling ln(Z):              -1710.464486
# Acceptance Rate:                        0.245293
# Replacements:                               4000
# Total Samples:                             16307
# Nested Sampling ln(Z):              -1692.915652
# Acceptance Rate:                        0.243258
# Replacements:                               4050
# Total Samples:                             16649
# Nested Sampling ln(Z):              -1676.065657
# Acceptance Rate:                        0.239542
# Replacements:                               4100
# Total Samples:                             17116
# Nested Sampling ln(Z):              -1659.152839
# Acceptance Rate:                        0.233856
# Replacements:                               4150
# Total Samples:                             17746
# Nested Sampling ln(Z):              -1641.574962
# Acceptance Rate:                        0.230769
# Replacements:                               4200
# Total Samples:                             18200
# Nested Sampling ln(Z):              -1625.183485
# Acceptance Rate:                        0.227406
# Replacements:                               4250
# Total Samples:                             18689
# Nested Sampling ln(Z):              -1608.324804
# Acceptance Rate:                        0.223435
# Replacements:                               4300
# Total Samples:                             19245
# Nested Sampling ln(Z):              -1591.623714
# Acceptance Rate:                        0.220812
# Replacements:                               4350
# Total Samples:                             19700
# Nested Sampling ln(Z):              -1574.734065
# Acceptance Rate:                        0.218092
# Replacements:                               4400
# Total Samples:                             20175
# Nested Sampling ln(Z):              -1555.808753
# Acceptance Rate:                        0.213922
# Replacements:                               4450
# Total Samples:                             20802
# Nested Sampling ln(Z):              -1543.436757
# Acceptance Rate:                        0.211834
# Replacements:                               4500
# Total Samples:                             21243
# Nested Sampling ln(Z):              -1526.704278
# Acceptance Rate:                        0.209157
# Replacements:                               4550
# Total Samples:                             21754
# Nested Sampling ln(Z):              -1511.426869
# Acceptance Rate:                        0.205183
# Replacements:                               4600
# Total Samples:                             22419
# Nested Sampling ln(Z):              -1493.830862
# Acceptance Rate:                        0.202042
# Replacements:                               4650
# Total Samples:                             23015
# Nested Sampling ln(Z):              -1479.131827
# Acceptance Rate:                        0.199601
# Replacements:                               4700
# Total Samples:                             23547
# Nested Sampling ln(Z):              -1467.085007
# Acceptance Rate:                        0.196908
# Replacements:                               4750
# Total Samples:                             24123
# Nested Sampling ln(Z):              -1454.272370
# Acceptance Rate:                        0.195027
# Replacements:                               4800
# Total Samples:                             24612
# Nested Sampling ln(Z):              -1441.374916
# Acceptance Rate:                        0.193296
# Replacements:                               4850
# Total Samples:                             25091
# Nested Sampling ln(Z):              -1429.943808
# Acceptance Rate:                        0.191376
# Replacements:                               4900
# Total Samples:                             25604
# Nested Sampling ln(Z):              -1416.298072
# Acceptance Rate:                        0.189924
# Replacements:                               4950
# Total Samples:                             26063
# Nested Sampling ln(Z):              -1403.264863
# Acceptance Rate:                        0.188182
# Replacements:                               5000
# Total Samples:                             26570
# Nested Sampling ln(Z):              -1390.611612
# Acceptance Rate:                        0.186436
# Replacements:                               5050
# Total Samples:                             27087
# Nested Sampling ln(Z):              -1380.465193
# Acceptance Rate:                        0.184242
# Replacements:                               5100
# Total Samples:                             27681
# Nested Sampling ln(Z):              -1365.120726
# Acceptance Rate:                        0.182961
# Replacements:                               5150
# Total Samples:                             28148
# Nested Sampling ln(Z):              -1348.481837
# Acceptance Rate:                        0.181071
# Replacements:                               5200
# Total Samples:                             28718
# Nested Sampling ln(Z):              -1335.868865
# Acceptance Rate:                        0.179899
# Replacements:                               5250
# Total Samples:                             29183
# Nested Sampling ln(Z):              -1319.532222
# Acceptance Rate:                        0.178650
# Replacements:                               5300
# Total Samples:                             29667
# Nested Sampling ln(Z):              -1310.601137
# Acceptance Rate:                        0.177041
# Replacements:                               5350
# Total Samples:                             30219
# Nested Sampling ln(Z):              -1294.747335
# Acceptance Rate:                        0.175610
# Replacements:                               5400
# Total Samples:                             30750
# Nested Sampling ln(Z):              -1279.035432
# Acceptance Rate:                        0.174730
# Replacements:                               5450
# Total Samples:                             31191
# Nested Sampling ln(Z):              -1263.868632
# Acceptance Rate:                        0.173365
# Replacements:                               5500
# Total Samples:                             31725
# Nested Sampling ln(Z):              -1246.747957
# Acceptance Rate:                        0.172162
# Replacements:                               5550
# Total Samples:                             32237
# Nested Sampling ln(Z):              -1229.000962
# Acceptance Rate:                        0.170202
# Replacements:                               5600
# Total Samples:                             32902
# Nested Sampling ln(Z):              -1211.602216
# Acceptance Rate:                        0.168125
# Replacements:                               5650
# Total Samples:                             33606
# Nested Sampling ln(Z):              -1193.010355
# Acceptance Rate:                        0.166598
# Replacements:                               5700
# Total Samples:                             34214
# Nested Sampling ln(Z):              -1179.009318
# Acceptance Rate:                        0.165083
# Replacements:                               5750
# Total Samples:                             34831
# Nested Sampling ln(Z):              -1163.284468
# Acceptance Rate:                        0.163749
# Replacements:                               5800
# Total Samples:                             35420
# Nested Sampling ln(Z):              -1146.905116
# Acceptance Rate:                        0.161714
# Replacements:                               5850
# Total Samples:                             36175
# Nested Sampling ln(Z):              -1132.244151
# Acceptance Rate:                        0.160243
# Replacements:                               5900
# Total Samples:                             36819
# Nested Sampling ln(Z):              -1115.343297
# Acceptance Rate:                        0.159406
# Replacements:                               5950
# Total Samples:                             37326
# Nested Sampling ln(Z):              -1102.102497
# Acceptance Rate:                        0.158789
# Replacements:                               6000
# Total Samples:                             37786
# Nested Sampling ln(Z):              -1082.274950
# Acceptance Rate:                        0.158232
# Replacements:                               6050
# Total Samples:                             38235
# Nested Sampling ln(Z):              -1062.040550
# Acceptance Rate:                        0.156679
# Replacements:                               6100
# Total Samples:                             38933
# Nested Sampling ln(Z):              -1050.316443
# Acceptance Rate:                        0.155894
# Replacements:                               6150
# Total Samples:                             39450
# Nested Sampling ln(Z):              -1038.131252
# Acceptance Rate:                        0.155019
# Replacements:                               6200
# Total Samples:                             39995
# Nested Sampling ln(Z):              -1019.804077
# Acceptance Rate:                        0.154180
# Replacements:                               6250
# Total Samples:                             40537
# Nested Sampling ln(Z):              -1007.066891
# Acceptance Rate:                        0.152838
# Replacements:                               6300
# Total Samples:                             41220
# Nested Sampling ln(Z):               -991.550771
# Acceptance Rate:                        0.151327
# Replacements:                               6350
# Total Samples:                             41962
# Nested Sampling ln(Z):               -977.927034
# Acceptance Rate:                        0.150238
# Replacements:                               6400
# Total Samples:                             42599
# Nested Sampling ln(Z):               -964.708742
# Acceptance Rate:                        0.148820
# Replacements:                               6450
# Total Samples:                             43341
# Nested Sampling ln(Z):               -947.918065
# Acceptance Rate:                        0.147808
# Replacements:                               6500
# Total Samples:                             43976
# Nested Sampling ln(Z):               -932.412808
# Acceptance Rate:                        0.146743
# Replacements:                               6550
# Total Samples:                             44636
# Nested Sampling ln(Z):               -920.301226
# Acceptance Rate:                        0.145387
# Replacements:                               6600
# Total Samples:                             45396
# Nested Sampling ln(Z):               -910.001306
# Acceptance Rate:                        0.144452
# Replacements:                               6650
# Total Samples:                             46036
# Nested Sampling ln(Z):               -895.979284
# Acceptance Rate:                        0.142866
# Replacements:                               6700
# Total Samples:                             46897
# Nested Sampling ln(Z):               -884.642291
# Acceptance Rate:                        0.142261
# Replacements:                               6750
# Total Samples:                             47448
# Nested Sampling ln(Z):               -871.427747
# Acceptance Rate:                        0.141355
# Replacements:                               6800
# Total Samples:                             48106
# Nested Sampling ln(Z):               -858.072008
# Acceptance Rate:                        0.140045
# Replacements:                               6850
# Total Samples:                             48913
# Nested Sampling ln(Z):               -843.829262
# Acceptance Rate:                        0.138861
# Replacements:                               6900
# Total Samples:                             49690
# Nested Sampling ln(Z):               -830.332043
# Acceptance Rate:                        0.137826
# Replacements:                               6950
# Total Samples:                             50426
# Nested Sampling ln(Z):               -816.894525
# Acceptance Rate:                        0.137032
# Replacements:                               7000
# Total Samples:                             51083
# Nested Sampling ln(Z):               -806.117212
# Acceptance Rate:                        0.136108
# Replacements:                               7050
# Total Samples:                             51797
# Nested Sampling ln(Z):               -795.486333
# Acceptance Rate:                        0.134569
# Replacements:                               7100
# Total Samples:                             52761
# Nested Sampling ln(Z):               -784.671740
# Acceptance Rate:                        0.133284
# Replacements:                               7150
# Total Samples:                             53645
# Nested Sampling ln(Z):               -772.422901
# Acceptance Rate:                        0.132514
# Replacements:                               7200
# Total Samples:                             54334
# Nested Sampling ln(Z):               -761.016880
# Acceptance Rate:                        0.131500
# Replacements:                               7250
# Total Samples:                             55133
# Nested Sampling ln(Z):               -748.228406
# Acceptance Rate:                        0.130724
# Replacements:                               7300
# Total Samples:                             55843
# Nested Sampling ln(Z):               -738.853208
# Acceptance Rate:                        0.129497
# Replacements:                               7350
# Total Samples:                             56758
# Nested Sampling ln(Z):               -727.915509
# Acceptance Rate:                        0.128646
# Replacements:                               7400
# Total Samples:                             57522
# Nested Sampling ln(Z):               -716.517808
# Acceptance Rate:                        0.127969
# Replacements:                               7450
# Total Samples:                             58217
# Nested Sampling ln(Z):               -707.945091
# Acceptance Rate:                        0.126977
# Replacements:                               7500
# Total Samples:                             59066
# Nested Sampling ln(Z):               -698.377593
# Acceptance Rate:                        0.126054
# Replacements:                               7550
# Total Samples:                             59895
# Nested Sampling ln(Z):               -687.065856
# Acceptance Rate:                        0.125400
# Replacements:                               7600
# Total Samples:                             60606
# Nested Sampling ln(Z):               -673.645457
# Acceptance Rate:                        0.124334
# Replacements:                               7650
# Total Samples:                             61528
# Nested Sampling ln(Z):               -665.758914
# Acceptance Rate:                        0.123155
# Replacements:                               7700
# Total Samples:                             62523
# Nested Sampling ln(Z):               -654.951905
# Acceptance Rate:                        0.122207
# Replacements:                               7750
# Total Samples:                             63417
# Nested Sampling ln(Z):               -645.494454
# Acceptance Rate:                        0.120971
# Replacements:                               7800
# Total Samples:                             64478
# Nested Sampling ln(Z):               -636.756677
# Acceptance Rate:                        0.120377
# Replacements:                               7850
# Total Samples:                             65212
# Nested Sampling ln(Z):               -628.718351
# Acceptance Rate:                        0.119438
# Replacements:                               7900
# Total Samples:                             66143
# Nested Sampling ln(Z):               -620.987238
# Acceptance Rate:                        0.118957
# Replacements:                               7950
# Total Samples:                             66831
# Nested Sampling ln(Z):               -612.027633
# Acceptance Rate:                        0.117898
# Replacements:                               8000
# Total Samples:                             67855
# Nested Sampling ln(Z):               -604.415336
# Acceptance Rate:                        0.116916
# Replacements:                               8050
# Total Samples:                             68853
# Nested Sampling ln(Z):               -596.605253
# Acceptance Rate:                        0.116191
# Replacements:                               8100
# Total Samples:                             69713
# Nested Sampling ln(Z):               -587.596469
# Acceptance Rate:                        0.115545
# Replacements:                               8150
# Total Samples:                             70535
# Nested Sampling ln(Z):               -580.619200
# Acceptance Rate:                        0.115039
# Replacements:                               8200
# Total Samples:                             71280
# Nested Sampling ln(Z):               -572.441288
# Acceptance Rate:                        0.114439
# Replacements:                               8250
# Total Samples:                             72091
# Nested Sampling ln(Z):               -564.144857
# Acceptance Rate:                        0.113531
# Replacements:                               8300
# Total Samples:                             73108
# Nested Sampling ln(Z):               -555.407829
# Acceptance Rate:                        0.112673
# Replacements:                               8350
# Total Samples:                             74108
# Nested Sampling ln(Z):               -548.774228
# Acceptance Rate:                        0.111778
# Replacements:                               8400
# Total Samples:                             75149
# Nested Sampling ln(Z):               -542.669358
# Acceptance Rate:                        0.111123
# Replacements:                               8450
# Total Samples:                             76042
# Nested Sampling ln(Z):               -536.269527
# Acceptance Rate:                        0.110059
# Replacements:                               8500
# Total Samples:                             77231
# Nested Sampling ln(Z):               -529.430674
# Acceptance Rate:                        0.109156
# Replacements:                               8550
# Total Samples:                             78328
# Nested Sampling ln(Z):               -522.861381
# Acceptance Rate:                        0.108284
# Replacements:                               8600
# Total Samples:                             79421
# Nested Sampling ln(Z):               -516.725857
# Acceptance Rate:                        0.107520
# Replacements:                               8650
# Total Samples:                             80450
# Nested Sampling ln(Z):               -509.738507
# Acceptance Rate:                        0.106123
# Replacements:                               8700
# Total Samples:                             81980
# Nested Sampling ln(Z):               -503.572243
# Acceptance Rate:                        0.105003
# Replacements:                               8750
# Total Samples:                             83331
# Nested Sampling ln(Z):               -496.611744
# Acceptance Rate:                        0.104073
# Replacements:                               8800
# Total Samples:                             84556
# Nested Sampling ln(Z):               -489.395621
# Acceptance Rate:                        0.102822
# Replacements:                               8850
# Total Samples:                             86071
# Nested Sampling ln(Z):               -484.486606
# Acceptance Rate:                        0.102001
# Replacements:                               8900
# Total Samples:                             87254
# Nested Sampling ln(Z):               -479.502844
# Acceptance Rate:                        0.101079
# Replacements:                               8950
# Total Samples:                             88545
# Nested Sampling ln(Z):               -474.381795
# Acceptance Rate:                        0.099813
# Replacements:                               9000
# Total Samples:                             90169
# Nested Sampling ln(Z):               -468.904043
# Acceptance Rate:                        0.098810
# Replacements:                               9050
# Total Samples:                             91590
# Nested Sampling ln(Z):               -463.805761
# Acceptance Rate:                        0.097149
# Replacements:                               9100
# Total Samples:                             93671
# Nested Sampling ln(Z):               -459.578485
# Acceptance Rate:                        0.096128
# Replacements:                               9150
# Total Samples:                             95186
# Nested Sampling ln(Z):               -454.770001
# Acceptance Rate:                        0.095113
# Replacements:                               9200
# Total Samples:                             96727
# Nested Sampling ln(Z):               -451.132875
# Acceptance Rate:                        0.094063
# Replacements:                               9250
# Total Samples:                             98338
# Nested Sampling ln(Z):               -447.624590
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.093098
# Replacements:                               9300
# Total Samples:                             99895
# Nested Sampling ln(Z):               -444.461324
# Acceptance Rate:                        0.092280
# Replacements:                               9350
# Total Samples:                            101322
# Nested Sampling ln(Z):               -440.205353
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.091429
# Replacements:                               9400
# Total Samples:                            102812
# Nested Sampling ln(Z):               -435.457799
# Acceptance Rate:                        0.090523
# Replacements:                               9450
# Total Samples:                            104393
# Nested Sampling ln(Z):               -431.340648
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.089416
# Replacements:                               9500
# Total Samples:                            106245
# Nested Sampling ln(Z):               -427.660074
# Acceptance Rate:                        0.088680
# Replacements:                               9550
# Total Samples:                            107690
# Nested Sampling ln(Z):               -424.058720
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.087281
# Replacements:                               9600
# Total Samples:                            109990
# Nested Sampling ln(Z):               -420.719549
# Acceptance Rate:                        0.086323
# Replacements:                               9650
# Total Samples:                            111789
# Nested Sampling ln(Z):               -417.225797
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.085473
# Replacements:                               9700
# Total Samples:                            113486
# Nested Sampling ln(Z):               -414.061934
# Acceptance Rate:                        0.084459
# Replacements:                               9750
# Total Samples:                            115440
# Nested Sampling ln(Z):               -410.680959
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.083260
# Replacements:                               9800
# Total Samples:                            117704
# Nested Sampling ln(Z):               -407.186398
# Acceptance Rate:                        0.082090
# Replacements:                               9850
# Total Samples:                            119990
# Nested Sampling ln(Z):               -403.773295
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.081130
# Replacements:                               9900
# Total Samples:                            122026
# Nested Sampling ln(Z):               -400.728049
# Acceptance Rate:                        0.080373
# Replacements:                               9950
# Total Samples:                            123798
# Nested Sampling ln(Z):               -397.629928
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.079169
# Replacements:                              10000
# Total Samples:                            126312
# Nested Sampling ln(Z):               -395.063668
# Acceptance Rate:                        0.077950
# Replacements:                              10050
# Total Samples:                            128929
# Nested Sampling ln(Z):               -391.913546
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.077057
# Replacements:                              10100
# Total Samples:                            131071
# Nested Sampling ln(Z):               -389.206383
# Acceptance Rate:                        0.075753
# Replacements:                              10150
# Total Samples:                            133988
# Nested Sampling ln(Z):               -386.747528
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.074701
# Replacements:                              10200
# Total Samples:                            136545
# Nested Sampling ln(Z):               -384.317929
# Acceptance Rate:                        0.073632
# Replacements:                              10250
# Total Samples:                            139206
# Nested Sampling ln(Z):               -381.759849
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.073061
# Replacements:                              10300
# Total Samples:                            140979
# Nested Sampling ln(Z):               -379.376212
# Acceptance Rate:                        0.072094
# Replacements:                              10350
# Total Samples:                            143563
# Nested Sampling ln(Z):               -376.848359
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.070900
# Replacements:                              10400
# Total Samples:                            146685
# Nested Sampling ln(Z):               -374.675009
# Acceptance Rate:                        0.069834
# Replacements:                              10450
# Total Samples:                            149641
# Nested Sampling ln(Z):               -372.102789
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.068694
# Replacements:                              10500
# Total Samples:                            152851
# Nested Sampling ln(Z):               -369.597713
# Acceptance Rate:                        0.067321
# Replacements:                              10550
# Total Samples:                            156712
# Nested Sampling ln(Z):               -367.414609
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.066227
# Replacements:                              10600
# Total Samples:                            160055
# Nested Sampling ln(Z):               -365.451038
# Acceptance Rate:                        0.065411
# Replacements:                              10650
# Total Samples:                            162816
# Nested Sampling ln(Z):               -363.057646
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.064555
# Replacements:                              10700
# Total Samples:                            165750
# Nested Sampling ln(Z):               -360.564288
# Acceptance Rate:                        0.063490
# Replacements:                              10750
# Total Samples:                            169317
# Nested Sampling ln(Z):               -358.267356
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.062612
# Replacements:                              10800
# Total Samples:                            172491
# Nested Sampling ln(Z):               -355.806566
# Acceptance Rate:                        0.062114
# Replacements:                              10850
# Total Samples:                            174679
# Nested Sampling ln(Z):               -353.069823
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.061602
# Replacements:                              10900
# Total Samples:                            176943
# Nested Sampling ln(Z):               -350.344651
# Acceptance Rate:                        0.061233
# Replacements:                              10950
# Total Samples:                            178825
# Nested Sampling ln(Z):               -347.564789
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.060982
# Replacements:                              11000
# Total Samples:                            180381
# Nested Sampling ln(Z):               -345.072277
# Acceptance Rate:                        0.060652
# Replacements:                              11050
# Total Samples:                            182187
# Nested Sampling ln(Z):               -341.130740
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.060177
# Replacements:                              11100
# Total Samples:                            184456
# Nested Sampling ln(Z):               -337.162570
# Acceptance Rate:                        0.059564
# Replacements:                              11150
# Total Samples:                            187193
# Nested Sampling ln(Z):               -334.173587
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.059198
# Replacements:                              11200
# Total Samples:                            189196
# Nested Sampling ln(Z):               -331.508129
# Acceptance Rate:                        0.058959
# Replacements:                              11250
# Total Samples:                            190812
# Nested Sampling ln(Z):               -327.885796
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.058682
# Replacements:                              11300
# Total Samples:                            192563
# Nested Sampling ln(Z):               -324.577938
# Acceptance Rate:                        0.058328
# Replacements:                              11350
# Total Samples:                            194588
# Nested Sampling ln(Z):               -321.631542
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.057889
# Replacements:                              11400
# Total Samples:                            196929
# Nested Sampling ln(Z):               -318.757190
# Acceptance Rate:                        0.057674
# Replacements:                              11450
# Total Samples:                            198529
# Nested Sampling ln(Z):               -315.851334
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.057534
# Replacements:                              11500
# Total Samples:                            199883
# Nested Sampling ln(Z):               -312.409171
# Acceptance Rate:                        0.057195
# Replacements:                              11550
# Total Samples:                            201940
# Nested Sampling ln(Z):               -309.370549
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.056798
# Replacements:                              11600
# Total Samples:                            204232
# Nested Sampling ln(Z):               -306.359948
# Acceptance Rate:                        0.056476
# Replacements:                              11650
# Total Samples:                            206282
# Nested Sampling ln(Z):               -304.171537
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.056232
# Replacements:                              11700
# Total Samples:                            208067
# Nested Sampling ln(Z):               -301.552049
# Acceptance Rate:                        0.055829
# Replacements:                              11750
# Total Samples:                            210465
# Nested Sampling ln(Z):               -298.724733
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.055555
# Replacements:                              11800
# Total Samples:                            212403
# ...
# Total Samples:                            555341
# Nested Sampling ln(Z):               -233.212803
# Acceptance Rate:                        0.027391
# Replacements:                              15450
# Total Samples:                            564062
# Nested Sampling ln(Z):               -233.030693
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.026997
# Replacements:                              15500
# Total Samples:                            574144
# Nested Sampling ln(Z):               -232.855897
# Acceptance Rate:                        0.026740
# Replacements:                              15550
# Total Samples:                            581531
# Nested Sampling ln(Z):               -232.689081
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.026423
# Replacements:                              15600
# Total Samples:                            590398
# Nested Sampling ln(Z):               -232.521796
# Acceptance Rate:                        0.026103
# Replacements:                              15650
# Total Samples:                            599552
# Nested Sampling ln(Z):               -232.360341
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.025797
# Replacements:                              15700
# Total Samples:                            608606
# Nested Sampling ln(Z):               -232.204578
# Acceptance Rate:                        0.025488
# Replacements:                              15750
# Total Samples:                            617940
# Nested Sampling ln(Z):               -232.057006
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.025127
# Replacements:                              15800
# Total Samples:                            628801
# Nested Sampling ln(Z):               -231.912774
# Acceptance Rate:                        0.024761
# Replacements:                              15850
# Total Samples:                            640109
# Nested Sampling ln(Z):               -231.776209
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.024517
# Replacements:                              15900
# Total Samples:                            648531
# Nested Sampling ln(Z):               -231.645005
# Acceptance Rate:                        0.024217
# Replacements:                              15950
# Total Samples:                            658615
# Nested Sampling ln(Z):               -231.516924
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.023916
# Replacements:                              16000
# Total Samples:                            669004
# Nested Sampling ln(Z):               -231.397612
# Acceptance Rate:                        0.023598
# Replacements:                              16050
# Total Samples:                            680153
# Nested Sampling ln(Z):               -231.280512
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.023357
# Replacements:                              16100
# Total Samples:                            689296
# Nested Sampling ln(Z):               -231.168838
# Acceptance Rate:                        0.023210
# Replacements:                              16150
# Total Samples:                            695807
# Nested Sampling ln(Z):               -231.063948
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.022895
# Replacements:                              16200
# Total Samples:                            707586
# Nested Sampling ln(Z):               -230.961981
# Acceptance Rate:                        0.022627
# Replacements:                              16250
# Total Samples:                            718181
# Nested Sampling ln(Z):               -230.862918
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.022385
# Replacements:                              16300
# Total Samples:                            728169
# Nested Sampling ln(Z):               -230.764062
# Acceptance Rate:                        0.022107
# Replacements:                              16350
# Total Samples:                            739597
# Nested Sampling ln(Z):               -230.669301
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.021818
# Replacements:                              16400
# Total Samples:                            751667
# Nested Sampling ln(Z):               -230.580171
# Acceptance Rate:                        0.021530
# Replacements:                              16450
# Total Samples:                            764066
# Nested Sampling ln(Z):               -230.495154
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.021298
# Replacements:                              16500
# Total Samples:                            774730
# Nested Sampling ln(Z):               -230.406900
# Acceptance Rate:                        0.021097
# Replacements:                              16550
# Total Samples:                            784488
# Nested Sampling ln(Z):               -230.322887
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.020849
# Replacements:                              16600
# Total Samples:                            796188
# Nested Sampling ln(Z):               -230.242989
# Acceptance Rate:                        0.020580
# Replacements:                              16650
# Total Samples:                            809034
# Nested Sampling ln(Z):               -230.165407
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.020313
# Replacements:                              16700
# Total Samples:                            822120
# Nested Sampling ln(Z):               -230.093331
# Acceptance Rate:                        0.020053
# Replacements:                              16750
# Total Samples:                            835279
# Nested Sampling ln(Z):               -230.025208
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.019816
# Replacements:                              16800
# Total Samples:                            847806
# Nested Sampling ln(Z):               -229.959854
# Acceptance Rate:                        0.019534
# Replacements:                              16850
# Total Samples:                            862582
# Nested Sampling ln(Z):               -229.897281
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.019165
# Replacements:                              16900
# Total Samples:                            881802
# Nested Sampling ln(Z):               -229.837001
# Acceptance Rate:                        0.018935
# Replacements:                              16950
# Total Samples:                            895166
# Nested Sampling ln(Z):               -229.780050
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.018671
# Replacements:                              17000
# Total Samples:                            910491
# Nested Sampling ln(Z):               -229.726602
# Acceptance Rate:                        0.018393
# Replacements:                              17050
# Total Samples:                            926986
# Nested Sampling ln(Z):               -229.676763
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.018112
# Replacements:                              17100
# Total Samples:                            944150
# Nested Sampling ln(Z):               -229.630125
# Acceptance Rate:                        0.017873
# Replacements:                              17150
# Total Samples:                            959532
# Nested Sampling ln(Z):               -229.586080
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.017640
# Replacements:                              17200
# Total Samples:                            975072
# Nested Sampling ln(Z):               -229.544329
# Acceptance Rate:                        0.017417
# Replacements:                              17250
# Total Samples:                            990431
# Nested Sampling ln(Z):               -229.504564
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.017123
# Replacements:                              17300
# Total Samples:                           1010308
# Nested Sampling ln(Z):               -229.467091
# Acceptance Rate:                        0.016853
# Replacements:                              17350
# Total Samples:                           1029492
# Nested Sampling ln(Z):               -229.431627
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.016545
# Replacements:                              17400
# Total Samples:                           1051683
# Nested Sampling ln(Z):               -229.398008
# Acceptance Rate:                        0.016318
# Replacements:                              17450
# Total Samples:                           1069362
# Nested Sampling ln(Z):               -229.366474
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.016107
# Replacements:                              17500
# Total Samples:                           1086482
# Nested Sampling ln(Z):               -229.336553
# Acceptance Rate:                        0.015909
# Replacements:                              17550
# Total Samples:                           1103161
# Nested Sampling ln(Z):               -229.308358
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.015660
# Replacements:                              17600
# Total Samples:                           1123859
# Nested Sampling ln(Z):               -229.281682
# Acceptance Rate:                        0.015384
# Replacements:                              17650
# Total Samples:                           1147299
# Nested Sampling ln(Z):               -229.256677
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.015138
# Replacements:                              17700
# Total Samples:                           1169281
# Nested Sampling ln(Z):               -229.232967
# Acceptance Rate:                        0.014943
# Replacements:                              17750
# Total Samples:                           1187853
# Nested Sampling ln(Z):               -229.210700
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.014715
# Replacements:                              17800
# Total Samples:                           1209642
# Nested Sampling ln(Z):               -229.189855
# Acceptance Rate:                        0.014503
# Replacements:                              17850
# Total Samples:                           1230783
# Nested Sampling ln(Z):               -229.170258
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.014319
# Replacements:                              17900
# Total Samples:                           1250069
# Nested Sampling ln(Z):               -229.151781
# Acceptance Rate:                        0.014176
# Replacements:                              17950
# Total Samples:                           1266236
# Nested Sampling ln(Z):               -229.134470
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.013928
# Replacements:                              18000
# Total Samples:                           1292315
# Nested Sampling ln(Z):               -229.118414
# Acceptance Rate:                        0.013670
# Replacements:                              18050
# Total Samples:                           1320444
# Nested Sampling ln(Z):               -229.103363
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.013446
# Replacements:                              18100
# Total Samples:                           1346084
# Nested Sampling ln(Z):               -229.089435
# Acceptance Rate:                        0.013251
# Replacements:                              18150
# Total Samples:                           1369667
# Nested Sampling ln(Z):               -229.076502
#
#  MultiNest Warning!
#  Parameter           11  of mode            1  is converging towards the edge of the prior.
# Acceptance Rate:                        0.013057
# Replacements:                              18200
# Total Samples:                           1393847
# Nested Sampling ln(Z):               -229.064554
# Acceptance Rate:                        0.012868
# Replacements:                              18250
# Total Samples:                           1418252
# Nested Sampling ln(Z):               -229.053468
# Acceptance Rate:                        0.012813
# Replacements:                              18270
# Total Samples:                           1425846
# Nested Sampling ln(Z):               -229.049202
#  ln(ev)=  -228.92393595119009      +/-  0.31516814305924062
#  Total Likelihood Evaluations:      1425846
#  Sampling finished. Exiting MultiNest
#
# Completed in 15089.1 seconds.
#
# Parameter                          Posterior percentiles
#                                 16th       50th       84th
# ----------------------------------------------------------
# calib:0                        0.928      1.099      1.258
# calib:1                        0.081      0.106      0.141
# calib:2                       -0.057     -0.049     -0.041
# dblplaw:alpha                  5.123      6.373      8.096
# dblplaw:beta                   0.038      0.425     15.481
# dblplaw:massformed             7.776      7.868      7.974
# dblplaw:metallicity            0.548      0.615      0.678
# dblplaw:tau                    3.382      4.985      6.557
# dust:Av                        0.050      0.160      0.340
# dust:n                         0.459      0.657      0.903
# noise:scaling                  1.000      1.001      1.003
# redshift                       0.047      0.047      0.047
# veldisp                      260.377    269.384    279.194
# /Users/yoachim/anaconda3/envs/glsb/lib/python3.11/site-packages/bagpipes/models/star_formation_history.py:278: RuntimeWarning: overflow encountered in power
#   sfr[mask] = ((t/tau)**alpha + (t/tau)**-beta)**-1

# %%
fig = fit.plot_spectrum_posterior(save=False, show=True)
fig = fit.plot_calibration(save=False, show=True)
fig = fit.plot_sfh_posterior(save=False, show=True)
fig = fit.plot_corner(save=True, show=True)

# %%
fig = fit.plot_spectrum_posterior(save=False, show=True)
fig = fit.plot_calibration(save=False, show=True)
fig = fit.plot_sfh_posterior(save=False, show=True)
fig = fit.plot_corner(save=True, show=True)

# %%
fit.plot_spectrum_posterior(show=True, save=False)
# Out:
# (<Figure size 1200x400 with 1 Axes>,
#  [<Axes: xlabel='$\\lambda / \\mathrm{\\AA}$', ylabel='$\\mathrm{f_{\\lambda}}\\ \\mathrm{/\\ 10^{-18}\\ erg\\ s^{-1}\\ cm^{-2}\\ \\AA^{-1}}$'>])

# %%
fit.posterior.samples["spectrum"].shape
# Out:
# (500, 1011)

# %%
fit.posterior.samples["spectrum"]
# Out:
# array([[4.45378434e-19, 4.77125385e-19, 4.93531652e-19, ...,
#         1.39769959e-18, 1.40102710e-18, 1.40063851e-18],
#        [4.58001437e-19, 4.91920021e-19, 5.09392342e-19, ...,
#         1.43812279e-18, 1.44185017e-18, 1.44159469e-18],
#        [3.62645428e-19, 3.88433324e-19, 4.01780641e-19, ...,
#         1.07761473e-18, 1.08002913e-18, 1.07961767e-18],
#        ...,
#        [2.73248323e-19, 2.93450864e-19, 3.03952463e-19, ...,
#         9.06236109e-19, 9.08478940e-19, 9.08288614e-19],
#        [4.10342192e-19, 4.40204109e-19, 4.54815774e-19, ...,
#         1.19084537e-18, 1.19336702e-18, 1.19260006e-18],
#        [3.22329457e-19, 3.45792012e-19, 3.57313492e-19, ...,
#         9.79388701e-19, 9.81548761e-19, 9.81078144e-19]])
